# %%
# ANALYSIS

#The following analysis was conducted on a school district to analyze
#how the school spending and size affect the students' performance. This
#was done by calculating the average reading, average math, and overall
#passing scores from each of the schools and then comparing them to the
#spending of the school. It can be seen that schools that spent less
#actually had overall better scores for reading, math, and overall
#passing percentages. However, this can also be because, the smaller
#the school, the less they are likely to spend. I came to this conclusion
#because the smaller the school, the better the scores were, too.
#Furthermore, it can also be seen that students who attended a charter
#versus district school performed better, too.
# Out:
#   Cell In[31], line 2
#     print("The following analysis was conducted on a school district to analyze
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()

school_count = school_data_complete['school_name'].nunique()

student_count = school_data_complete['Student ID'].count()

# Calculate the total budget
total_budget = school_data['budget'].sum()

# Calculate the average (mean) math score
average_math_score = school_data_complete['math_score'].mean()

# Calculate the average (mean) reading score
average_reading_score = school_data_complete['reading_score'].mean()

passing_math_count = school_data_complete[(school_data_complete["math_score"] >= 70)].count()["student_name"]
passing_math_percentage = passing_math_count / float(student_count) * 100
passing_math_percentage

# Count the number of students who passed reading (scored 70 or above)
passing_reading_count = school_data_complete[school_data_complete["reading_score"] >= 70].count()["student_name"]

# Calculate the percentage of students who passed reading
passing_reading_percentage = passing_reading_count / float(student_count) * 100

passing_math_reading_count = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
overall_passing_rate = passing_math_reading_count /  float(student_count) * 100
overall_passing_rate
# Calculate total number of students
total_students = student_count

# Calculate total budget
total_budget_formatted = "${:,.2f}".format(total_budget)

# Calculate average math score
average_math_score_formatted = "{:.2f}".format(average_math_score)

# Calculate average reading score
average_reading_score_formatted = "{:.2f}".format(average_reading_score)

# Calculate percentage of students passing math
passing_math_percentage_formatted = "{:.2f}%".format(passing_math_percentage)

# Calculate percentage of students passing reading
passing_reading_percentage_formatted = "{:.2f}%".format(passing_reading_percentage)

# Create DataFrame
district_summary = pd.DataFrame({
    "Total Students": [total_students],
    "Total Budget": [total_budget_formatted],
    "Average Math Score": [average_math_score_formatted],
    "Average Reading Score": [average_reading_score_formatted],
    "% Passing Math": [passing_math_percentage_formatted],
    "% Passing Reading": [passing_reading_percentage_formatted]
})

# Display the DataFrame
district_summary
# Out:
#    Total Students    Total Budget Average Math Score Average Reading Score  \
# 0           39170  $24,649,428.00              78.99                 81.88
#
#   % Passing Math % Passing Reading
# 0         74.98%            85.81%

# %%
# Calculate the total school budget per school
per_school_budget = school_data.set_index("school_name")["budget"]

# Calculate the per capita spending per school
per_school_capita = per_school_budget / per_school_counts

# Convert Series to DataFrame
per_school_budget_df = per_school_budget.to_frame(name="Total School Budget")
per_school_capita_df = per_school_capita.to_frame(name="Per Capita Spending")

# Display the results in nicer formatted tables
print("Total school budget per school:")
display(per_school_budget_df.style.set_caption("Total School Budget").set_properties(**{'text-align': 'center'}))

print("\nPer capita spending per school:")
display(per_school_capita_df.style.set_caption("Per Capita Spending").set_properties(**{'text-align': 'center'}))
# Out:
# Total school budget per school:
# <style type="text/css">
# #T_3a801_row0_col0, #T_3a801_row1_col0, #T_3a801_row2_col0, #T_3a801_row3_col0, #T_3a801_row4_col0, #T_3a801_row5_col0, #T_3a801_row6_col0, #T_3a801_row7_col0, #T_3a801_row8_col0, #T_3a801_row9_col0, #T_3a801_row10_col0, #T_3a801_row11_col0, #T_3a801_row12_col0, #T_3a801_row13_col0, #T_3a801_row14_col0 {
#   text-align: center;
# }
# </style>
# <table id="T_3a801">
#   <caption>Total School Budget</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a801_level0_col0" class="col_heading level0 col0" >Total School Budget</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a801_level0_row0" class="row_heading level0 row0" >Huang High School</th>
#       <td id="T_3a801_row0_col0" class="data row0 col0" >1910635</td>
#     </tr>
#     <tr>
# ...

# %%
# Assuming 'students_passing_math' is a Series object containing the number of students passing math per school
students_passing_math_df = students_passing_math.to_frame(name="Number of Students Passing Math")

# Assuming 'school_students_passing_math' is a Series object containing the percentage of students passing math per school
school_students_passing_math_df = school_students_passing_math.to_frame(name="Percentage of Students Passing Math")

# Display the results in nicer formatted tables
print("Number of students passing math per school:")
display(students_passing_math_df.style.set_caption("Number of Students Passing Math").set_properties(**{'text-align': 'center'}))

print("\nPercentage of students passing math per school:")
display(school_students_passing_math_df.style.set_caption("Percentage of Students Passing Math").set_properties(**{'text-align': 'center'}))
# Out:
# Number of students passing math per school:
# <style type="text/css">
# #T_afa20_row0_col0, #T_afa20_row1_col0, #T_afa20_row2_col0, #T_afa20_row3_col0, #T_afa20_row4_col0, #T_afa20_row5_col0, #T_afa20_row6_col0, #T_afa20_row7_col0, #T_afa20_row8_col0, #T_afa20_row9_col0, #T_afa20_row10_col0, #T_afa20_row11_col0, #T_afa20_row12_col0, #T_afa20_row13_col0, #T_afa20_row14_col0 {
#   text-align: center;
# }
# </style>
# <table id="T_afa20">
#   <caption>Number of Students Passing Math</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afa20_level0_col0" class="col_heading level0 col0" >Number of Students Passing Math</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afa20_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
# ...

# %%
# Assuming 'students_passing_reading' is a Series object containing the number of students passing reading per school
students_passing_reading_df = students_passing_reading.to_frame(name="Number of Students Passing Reading")

# Assuming 'school_students_passing_reading' is a Series object containing the percentage of students passing reading per school
school_students_passing_reading_df = school_students_passing_reading.to_frame(name="Percentage of Students Passing Reading")

# Display the results in dataframes
print("Number of students passing reading per school:")
display(students_passing_reading_df)

print("\nPercentage of students passing reading per school:")
display(school_students_passing_reading_df)
# Out:
# Number of students passing reading per school:
#                        Number of Students Passing Reading
# school_name
# Bailey High School                                   4077
# Cabrera High School                                  1803
# Figueroa High School                                 2381
# Ford High School                                     2172
# Griffin High School                                  1426
# Hernandez High School                                3748
# Holden High School                                    411
# Huang High School                                    2372
# Johnson High School                                  3867
# Pena High School                                      923
# Rodriguez High School                                3208
# Shelton High School                                  1688
# Thomas High School                                   1591
# Wilson High School                                   2204
# ...

# %%
# Calculate the total number of schools
total_schools = school_data_complete['school_name'].nunique()

# Calculate the total number of students
total_students = school_data_complete['Student ID'].count()

# Calculate the total budget
total_budget = school_data['budget'].sum()

# Calculate the average math score
average_math_score = school_data_complete['math_score'].mean()

# Calculate the average reading score
average_reading_score = school_data_complete['reading_score'].mean()

# Calculate the percentage of students passing math
passing_math_percentage = (school_data_complete['math_score'] >= 70).mean() * 100

# Calculate the percentage of students passing reading
passing_reading_percentage = (school_data_complete['reading_score'] >= 70).mean() * 100

# Calculate the overall passing rate (percentage of students passing both math and reading)
overall_passing_percentage = (school_data_complete[(school_data_complete['math_score'] >= 70) & 
                                                   (school_data_complete['reading_score'] >= 70)].shape[0] / total_students) * 100

# 1. Summary Metrics by School
# Calculate the necessary metrics
per_school_summary = pd.DataFrame({
    "School Type": school_types,
    "Total Students": per_school_counts,
    "Total School Budget": per_school_budget,
    "Per Student Budget": per_school_capita,
    "Average Math Score": per_school_math,
    "Average Reading Score": per_school_reading,
    "% Passing Math": school_students_passing_math,
    "% Passing Reading": school_students_passing_reading,
    "% Overall Passing": school_students_passing_math_and_reading / per_school_counts * 100
})

# Sort the schools by % Overall Passing in descending order and get top 5
top_schools = per_school_summary.sort_values(by="% Overall Passing", ascending=False).head(5)

# Sort the schools by % Overall Passing in ascending order and get top 5
bottom_schools = per_school_summary.sort_values(by="% Overall Passing").head(5)

# Display top performing schools
print("Top Performing Schools (by % Overall Passing):")
display(top_schools)

# Display bottom performing schools
print("\nBottom Performing Schools (by % Overall Passing):")
display(bottom_schools)
# Out:
# Top Performing Schools (by % Overall Passing):
#                     School Type  Total Students  Total School Budget  \
# school_name
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %%
# Format the calculated values
total_budget_formatted = "${:,.2f}".format(total_budget)
average_math_score_formatted = "{:.2f}".format(average_math_score)
average_reading_score_formatted = "{:.2f}".format(average_reading_score)
passing_math_percentage_formatted = "{:.2f}%".format(passing_math_percentage)
passing_reading_percentage_formatted = "{:.2f}%".format(passing_reading_percentage)
overall_passing_percentage_formatted = "{:.2f}%".format(overall_passing_percentage)

# Create a DataFrame
district_summary = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget_formatted],
    "Average Math Score": [average_math_score_formatted],
    "Average Reading Score": [average_reading_score_formatted],
    "% Passing Math": [passing_math_percentage_formatted],
    "% Passing Reading": [passing_reading_percentage_formatted],
    "% Overall Passing Rate": [overall_passing_percentage_formatted]
})

# Display the DataFrame
display(district_summary)

# 2. Math and Reading Scores by Grade
# Create DataFrames for math and reading scores by grade
math_scores_by_grade = school_data_complete.pivot_table(values='math_score', index='school_name', columns='grade', aggfunc='mean')
reading_scores_by_grade = school_data_complete.pivot_table(values='reading_score', index='school_name', columns='grade', aggfunc='mean')

# Display math scores by grade
print("\nMath Scores by Grade:")
display(math_scores_by_grade)

# Display reading scores by grade
print("\nReading Scores by Grade:")
display(reading_scores_by_grade)
# Out:
#    Total Schools  Total Students    Total Budget Average Math Score  \
# 0             15           39170  $24,649,428.00              78.99
#
#   Average Reading Score % Passing Math % Passing Reading  \
# 0                 81.88         74.98%            85.81%
#
#   % Overall Passing Rate
# 0                 65.17%
# Math Scores by Grade:
# grade                       10th       11th       12th        9th
# school_name
# Bailey High School     76.996772  77.515588  76.492218  77.083676
# Cabrera High School    83.154506  82.765560  83.277487  83.094697
# Figueroa High School   76.539974  76.884344  77.151369  76.403037
# Ford High School       77.672316  76.918058  76.179963  77.361345
# Griffin High School    84.229064  83.842105  83.356164  82.044010
# Hernandez High School  77.337408  77.136029  77.186567  77.438495
# Holden High School     83.429825  85.000000  82.855422  83.787402
# Huang High School      75.908735  76.446602  77.225641  77.027251
# ...

# %%
# Bin the schools based on spending per student
spending_bins = [0, 585, 630, 645, 680]
spending_labels = ["<$585", "$585-630", "$630-645", "$645-680"]
per_school_summary["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=spending_labels)

# Calculate mean scores and passing percentages per spending range
spending_summary = per_school_summary.groupby("Spending Ranges (Per Student)").agg({
    "Average Math Score": "mean",
    "Average Reading Score": "mean",
    "% Passing Math": "mean",
    "% Passing Reading": "mean",
    "% Overall Passing": "mean"
})

# Display the spending summary
print("\nScores by School Spending:")
display(spending_summary)
# Out:
# Scores by School Spending:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-630                                81.899826              83.155286
# $630-645                                78.518855              81.624473
# $645-680                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-630                            87.133538          92.718205
# $630-645                            73.484209          84.391793
# $645-680                            66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-630                               81.418596
# ...

# %%
# Calculate mean scores and passing percentages per size category
size_summary = per_school_summary.groupby("School Size").agg({
    "Average Math Score": "mean",
    "Average Reading Score": "mean",
    "% Passing Math": "mean",
    "% Passing Reading": "mean",
    "% Overall Passing": "mean"
})

# Display the size summary
print("\nScores by School Size:")
display(size_summary)
# Out:
# Scores by School Size:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %%
type_summary = per_school_summary.groupby("School Type").agg({
    "Average Math Score": "mean",
    "Average Reading Score": "mean",
    "% Passing Math": "mean",
    "% Passing Reading": "mean",
    "% Overall Passing": "mean"
})

# Display the type summary
print("\nScores by School Type:")
display(type_summary)
# Out:
# Scores by School Type:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
